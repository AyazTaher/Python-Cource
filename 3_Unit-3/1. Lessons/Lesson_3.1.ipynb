# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة الثالثة: العمليات في البايثون</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الدرس 3.1 – العمليات الحسابية في بايثون</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 1-	 العمليات البسيطة</div>

# %%
#Addition of two numbers 
a = 15 
b = 4 
print("Addition:", a + b) 
print("Subtraction:", a - b) 
print("Multiplication:", a * b) 
print("Division (float):", a / b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division (float): 3.75

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 2-	 القسمة الصحيحة وباقي القسمة</div>

# %%
x = 17
y = 5

# gives an integer result 
print("Integer Division:", x // y) 

# gives the remainder after division
print("Remainder:", x % y)
# Out:
# Integer Division: 3
# Remainder: 2

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 3-	 رفع العدد لقوة</div>

# %%
base = 3
power = 4

print("Power result:", base ** power)
# Out:
# Power result: 81

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# تمرين
# المطلوب
# اكتب برنامجًا يطلب من المستخدم إدخال عددين، ثم يعرض
#
# 1.	حاصل جمعهما
# 2.	حاصل طرح الأول من الثاني
# 3.	حاصل ضربهما
# 4.	ناتج قسمة الأول على الثاني (قسمة عشرية)
# 5.	ناتج القسمة الصحيحة
# 6.	باقي القسمة
# 7.	الأول مرفوع للقوة الثانية
#
# الحل </div>

# %%
# Input numbers from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

#1
print("Addition:", num1 + num2)

#2
print("Subtraction:", num1 - num2)

#3
print("Multiplication:", num1 * num2)

#4
print("Division (float):", num1 / num2)

#5
print("Integer Division:", num1 // num2)

#6
print("Remainder:", num1 % num2)

#7
print("First number squared:", num1 ** 2)
# Out:
# Addition: 7.0
# Subtraction: -3.0
# Multiplication: 10.0
# Division (float): 0.4
# Integer Division: 0.0
# Remainder: 2.0
# First number squared: 4.0
