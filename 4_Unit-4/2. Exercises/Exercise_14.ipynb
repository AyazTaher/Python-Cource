# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة الرابعة:   التمرين الرابع عشر  Exercise_14</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 1 – التحقق من الرقم الزوجي
# المطلوب:
#
# اطلب من المستخدم إدخال رقم، ثم:
#
# •	اطبع "زوجي" إذا كان الرقم زوجيًا، وإلا اطبع "فردي"، باستخدام المشروط الثلاثي (x if condition else y) بدلاً من if-else التقليدي.
#
# الحل:
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#
# التمرين 2 – التحقق من العمر للتصويت
# المطلوب:
#
# اطلب من المستخدم إدخال العمر، ثم:
# - 	إذا كان العمر ≥ 18 → "مؤهل للتصويت"، وإلا → "غير مؤهل".
# - 	استخدم اختصار الجملة الشرطية بدل if-else الطويلة.
#
# الحل:
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#
# </div>
