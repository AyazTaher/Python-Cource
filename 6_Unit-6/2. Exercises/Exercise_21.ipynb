# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة السادسة:   التمرين الحادي و العشرون   Exercise_21</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 1 – دالة لحساب القوة مع قيمة أس افتراضية
#
# اكتب دالة باسم power(base, exponent=2) تستقبل رقمين:
#
# base العدد الأساسي
#
# exponent الأس، وهو اختياري وقيمته الافتراضية 2
#
# تعيد الدالة base مرفوعًا إلى exponent.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 2 – دالة تحسب السعر بعد خصم افتراضي
#
# اكتب دالة باسم discount(price, rate=0.1) تستقبل السعر price ونسبة الخصم rate (افتراضية 10%)،
#
# وتعيد السعر بعد تطبيق الخصم. هنا النص
#
# </div>
