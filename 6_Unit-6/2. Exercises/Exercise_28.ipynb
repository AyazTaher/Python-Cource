# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة السادسة:   التمرين الثامن و العشرون   Exercise_28</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 1 – دالة ترحيب بسيطة
#
# المطلوب:
#
# أنشئ دالة باسم welcome_message تستقبل اسم شخص واحد.
#
# اطبع رسالة ترحيب به.
#
# أضف Docstring يوضح وظيفة الدالة، المعاملات، والقيمة المرجعة (إذا وجدت).
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 2 – دالة جمع أرقام
#
# المطلوب:
#
# أنشئ دالة باسم sum_three_numbers تستقبل ثلاثة أرقام.
#
# ترجع مجموعهم.
#
# أضف Docstring يوضح وظيفة الدالة، نوع المعاملات، والقيمة المرجعة.
# </div>
