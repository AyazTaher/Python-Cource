# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة السادسة:   التمرين العشرون   Exercise_20</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 1 – دالة ترحب بالمستخدم
#
# اكتب دالة باسم greet_user() لا تستقبل أي معاملات، وعند استدعائها تقوم بطباعة رسالة ترحيب مثل:
#
# "مرحبًا بك في دورة بايثون!"
#
# ثم قم باستدعاء الدالة لاختبارها.
# </div>

# %%
def greet_user():
    print("Welcome to the Python course!")
    
greet_user()
# Out:
# Welcome to the Python course!

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 2 – دالة تجمع رقمين وترجع النتيجة
#
#
# اكتب دالة باسم add_numbers(a, b) تستقبل رقمين كوسيطين،
# وتُعيد ناتج جمعهما (وليس طباعته فقط).
# ثم اطبع النتيجة
# </div>

# %%
def add_numbers(a, b):
    return a + b
print("add_numbers(5,7) =", add_numbers(5, 7))
# Out:
# add_numbers(5,7) = 12
