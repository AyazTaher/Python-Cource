# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة السادسة:   المهمة الثالثة و العشرون   Task_23</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 1 – ربط دالتين: استخدام دالة داخل أخرى
#
# المطلوب:
#
# أنشئ دالة multiply(a,b) تعيد حاصل ضرب الرقمين.
#
# أنشئ دالة triple_sum(x,y) تستخدم multiply لحساب (x+y)*3.
# </div>

# %%
def multiply(a, b):
    return a * b

def triple_sum(x, y):
    return multiply(x + y, 3)

print(triple_sum(4, 5))
# Out:
# 27

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 2 – دالة تتحقق من الرقم وترجع رسالة
#
# المطلوب:
#
# أنشئ دالة باسم check_sign تستقبل رقمًا وتعيد "موجب" إذا الرقم > 0، "سالب" إذا < 0، و "صفر" إذا = 0.
# </div>

# %%
def check_sign(n):
    if n > 0:
        return "Positive"
    elif n < 0:
        return "Negative"
    else:
        return "Zero"
    
print(check_sign(-12))
print(check_sign(0))
print(check_sign(7))
# Out:
# Negative
# Zero
# Positive

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 3 – استكشاف النطاق المحلي والعالمي
#
# المطلوب:
#
# أنشئ متغيرًا عالميًا x = 100.
#
# أنشئ دالة local_test() تعرّف متغيرًا محليًا بنفس الاسم x = 50 وتطبعه.
# </div>

# %%
x = 100  # Global variable

def local_test():
    x = 50  # Local variable
    print("Inside the function:", x)

local_test()
print("Outside the function:", x)
# Out:
# Inside the function: 50
# Outside the function: 100

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 4 – تعديل متغير عالمي باستخدام global
#
# المطلوب:
#
# أنشئ متغيرًا عالميًا counter = 0.
#
# أنشئ دالة increment_counter() تستخدم global لتعديل قيمة counter بمقدار +1 كل مرة.
# </div>

# %%
counter = 0

def increment_counter():
    global counter
    counter += 1
    print("Inside the function:", counter)

increment_counter()
increment_counter()
increment_counter()
print("Outside the function:", counter)
# Out:
# Inside the function: 1
# Inside the function: 2
# Inside the function: 3
# Outside the function: 3
