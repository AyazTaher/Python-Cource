# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة السادسة:   التمرين السادس و العشرون   Exercise_26</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 1 – مربع رقم
#
# أنشئ دالة Lambda لحساب مربع أي رقم.
# </div>

# %%
square = lambda x: x**2
print(square(6))  # 36
# Out:
# 36
