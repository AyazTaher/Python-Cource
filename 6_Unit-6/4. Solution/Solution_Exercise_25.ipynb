# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة السادسة:   التمرين الخامس والعشرون   Exercise_25</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 1 – دالة داخل دالة بسيطة
#
# المطلوب:
#
# أنشئ دالة خارجية باسم outer_function تقوم بطباعة "هذه الدالة الخارجية".
#
# داخلها، أنشئ دالة داخلية باسم inner_function تطبع "هذه الدالة الداخلية".
#
# استدعِ الدالة الداخلية داخل الخارجية.
# </div>

# %%
def outer_function():
    print("This is the outer function")

    def inner_function():
        print("This is the inner function")
        
    inner_function()

outer_function()
# Out:
# This is the outer function
# This is the inner function

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 2 – دالة داخلية لمعالجة نصوص
#
# المطلوب:
#
# أنشئ دالة باسم greet_user(name) تستقبل اسم المستخدم.
#
# داخلها دالة format_name() تقوم بتحويل الاسم إلى حروف كبيرة.
#
# اطبع رسالة ترحيب باستخدام الاسم بعد تنسيقه.
# </div>

# %%
def greet_user(name):
    def format_name():
        return name.upper()
    print(f"Hello {format_name()}!")

greet_user("ayaz")
# Out:
# Hello AYAZ!
