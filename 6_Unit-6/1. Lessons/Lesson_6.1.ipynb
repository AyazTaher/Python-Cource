# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة السادسة: الدوال في بايثون</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# Functions in Python</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الدرس 6.1 – إنشاء الدوال واستدعاؤها</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 1-	 دالة بدون معاملات ولا قيمة مرجعة</div>

# %%
def greet():
    print("Welcome to the world of programming!")

# Calling the function
greet()
# Out:
# Welcome to the world of programming!

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 2-	 دالة تأخذ معاملات ولا ترجع قيمة</div>

# %%
# A function that takes parameters but does not return a value
def add_numbers(a, b):
    result = a + b
    print(f"The result is: {result}")

# Calling the function
add_numbers(20, 50)
# Out:
# The result is: 70

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 3-	 دالة ترجع قيمة</div>

# %%
# A function that returns a value
def square(number):
    return number * number

result = square(20)
print(f"The square of 5 is: {result}")
# Out:
# The square of 5 is: 400

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# 4-	 دالة تستدعي دالة أخرى</div>

# %%
# A function that calls another function
def say_hello():
    print("Hello!")

def welcome():
    say_hello()
    print("Welcome to the course.")
    
welcome()
# Out:
# Hello!
# Welcome to the course.

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# تمرين
#
# أنشئ دالة باسم
#
# print_name
#
# تأخذ اسمًا كمعامل وتطبع
#
#
# اسمي هو: {الاسم}
#
#
# ثم استدعها مع اسمك
#
# الحل
# </div>

# %%
# Exercise:
def print_name(name):
    print(f"My name is: {name}")

print_name("Dan")
# Out:
# My name is: Dan
