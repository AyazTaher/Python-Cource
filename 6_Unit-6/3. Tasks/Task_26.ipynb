# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة السادسة:   المهمة السادسة و العشرون   Task_26</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 1 – جمع رقمين
#
# أنشئ Lambda لجمع رقمين.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 2 – التحقق من زوجية الرقم
#
# أنشئ Lambda تُعيد "زوجي" إذا كان الرقم زوجيًا و"فردي" إذا كان فرديًا.
# </div>
