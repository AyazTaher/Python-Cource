# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة الثانية:   التمرين الرابع  Exercise_4</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# التمرين 1: درجات الطلاب في مواد متعددة
#
# grades = [
#     [90, 85, 88],
#     [70, 75, 80],
#     [100, 95, 98],
#     [60, 55, 70]
# ]
# المطلوب:
# 1.	احسب عدد الطلاب.
# 2.	احسب مجموع الدرجات لكل طالب (قائمة جديدة).
# 3.	احسب المتوسط العام لجميع الدرجات في الصف.
# 4.	أوجد أعلى درجة بين جميع الطلاب.
# 5.	اجمع الدرجات في قائمة واحدة فقط (بدون الحلقات).
#
# الحل
#
#
#
#
# </div>

# %%
grades = [
    [90, 85, 88],
    [70, 75, 80],
    [100, 95, 98],
    [60, 55, 70]
]

# 1
num_students = len(grades)

# 2
total_per_student = [sum(grades[0]), sum(grades[1]), sum(grades[2]), sum(grades[3])]

# 3
overall_average = (sum(sum(grades, []))) / (len(sum(grades, [])))

# 4
highest_grade = max(sum(grades, []))

# 5
flat_list = sum(grades, [])

print(num_students)
print(total_per_student)
print(overall_average)
print(highest_grade)
print(flat_list)
# Out:
# 4
# [263, 225, 293, 185]
# 80.5
# 100
# [90, 85, 88, 70, 75, 80, 100, 95, 98, 60, 55, 70]

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# التمرين 2: أسعار منتجات في فروع مختلفة
#
# prices = [
#     [20, 25, 22],
#     [18, 30, 27],
#     [21, 19, 23]
# ]
#
# المطلوب:
# 1.	احسب متوسط الأسعار في كل فرع.
# 2.	أوجد أقل سعر من بين كل الفروع.
# 3.	اجمع الأسعار في قائمة واحدة.
# 4.	احسب مجموع أسعار الأعمدة (المنتجات نفسها في كل الفروع).
# 5.	استخرج أعلى سعر في كل فرع.
# الحل
#
# </div>

# %%
prices = [
    [20, 25, 22],
    [18, 30, 27],
    [21, 19, 23]
]

# 1
avg_per_branch = [sum(prices[0])/len(prices[0]), sum(prices[1])/len(prices[1]), sum(prices[2])/len(prices[2])]

# 2
lowest_price = min(sum(prices, []))

# 3
all_prices = sum(prices, [])

# 4
total_per_product = [prices[0][0]+prices[1][0]+prices[2][0],
                     prices[0][1]+prices[1][1]+prices[2][1],
                     prices[0][2]+prices[1][2]+prices[2][2]]

# 5
max_per_branch = [max(prices[0]), max(prices[1]), max(prices[2])]

print(avg_per_branch)
print(lowest_price)
print(all_prices)
print(total_per_product)
print(max_per_branch)
# Out:
# [22.333333333333332, 25.0, 21.0]
# 18
# [20, 25, 22, 18, 30, 27, 21, 19, 23]
# [59, 74, 72]
# [25, 30, 23]

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# التمرين 3: درجات الطلبة في ثلاث امتحانات
#
# scores = [
#     [50, 60, 70],
#     [80, 85, 90],
#     [40, 55, 65],
#     [90, 92, 95]
# ]
#
# المطلوب:
# 1.	احسب متوسط كل طالب.
# 2.	احسب أعلى متوسط.
# 3.	احسب أدنى درجة في جميع الامتحانات.
# 4.	اجمع كل الدرجات في قائمة واحدة بدون تكرار.
# 5.	رتب كل قائمة فرعية تنازليًا (بدون sorted).
#
# الحل:
#
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#
# </div>

# %%
scores = [
    [50, 60, 70],
    [80, 85, 90],
    [40, 55, 65],
    [90, 92, 95]
]

# 1
avg_each = [sum(scores[0])/len(scores[0]), sum(scores[1])/len(scores[1]),
            sum(scores[2])/len(scores[2]), sum(scores[3])/len(scores[3])]

# 2
highest_avg = max(avg_each)

# 3
min_score = min(sum(scores, []))

# 4
unique_scores = list(set(sum(scores, [])))

# 5 (بدون sorted، سنستخدم .sort(reverse=True))
scores[0].sort(reverse=True)
scores[1].sort(reverse=True)
scores[2].sort(reverse=True)
scores[3].sort(reverse=True)

print(avg_each)
print(highest_avg)
print(min_score)
print(unique_scores)
print(scores)
# Out:
# [60.0, 85.0, 53.333333333333336, 92.33333333333333]
# 92.33333333333333
# 40
# [65, 70, 40, 92, 80, 50, 85, 55, 90, 60, 95]
# [[70, 60, 50], [90, 85, 80], [65, 55, 40], [95, 92, 90]]

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# التمرين 4: بيانات المبيعات الشهرية
#
# sales = [
#     [1200, 1500, 1300],
#     [1100, 1250, 1400],
#     [1000, 950, 1200],
#     [2000, 1850, 2100]
# ]
#
# المطلوب:
# 1.	احسب إجمالي مبيعات كل فرع.
# 2.	احسب المتوسط الشهري العام لجميع الفروع.
# 3.	اجمع جميع المبيعات في قائمة واحدة.
# 4.	استخرج أعلى مبيعات شهرية لكل فرع.
# 5.	استخرج مجموع مبيعات كل شهر في جميع الفروع.
# 6.	اعكس ترتيب كل قائمة فرعية.
# الحل:
#
#
#
#
# </div>

# %%
sales = [
    [1200, 1500, 1300],
    [1100, 1250, 1400],
    [1000, 950, 1200],
    [2000, 1850, 2100]
]

# 1
total_branch = [sum(sales[0]), sum(sales[1]), sum(sales[2]), sum(sales[3])]

# 2
avg_all = sum(sum(sales, [])) / len(sum(sales, []))

# 3
flat_sales = sum(sales, [])

# 4
max_per_branch = [max(sales[0]), max(sales[1]), max(sales[2]), max(sales[3])]

# 5
total_per_month = [sales[0][0]+sales[1][0]+sales[2][0]+sales[3][0],
                   sales[0][1]+sales[1][1]+sales[2][1]+sales[3][1],
                   sales[0][2]+sales[1][2]+sales[2][2]+sales[3][2]]

# 6
sales[0] = sales[0][::-1]
sales[1] = sales[1][::-1]
sales[2] = sales[2][::-1]
sales[3] = sales[3][::-1]

print(total_branch)
print(avg_all)
print(flat_sales)
print(max_per_branch)
print(total_per_month)
print(sales)
# Out:
# [4000, 3750, 3150, 5950]
# 1404.1666666666667
# [1200, 1500, 1300, 1100, 1250, 1400, 1000, 950, 1200, 2000, 1850, 2100]
# [1500, 1400, 1200, 2100]
# [5300, 5550, 6000]
# [[1300, 1500, 1200], [1400, 1250, 1100], [1200, 950, 1000], [2100, 1850, 2000]]
