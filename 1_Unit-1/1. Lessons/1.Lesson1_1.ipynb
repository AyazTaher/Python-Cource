# %% [markdown]
# <div dir="rtl" style="text-align: right;">

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# الوحدة الأولى – مقدمة إلى بايثون
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# الدرس 1.1: تاريخ بايثون ولماذا هي لغة سهلة ومرنة
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 1-	 أول برنامج في بايثون (Hello World)
# </div>

# %%
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 2-	كتابة جملة ترحيبية باسمك
# </div>

# %%
name = "Ayaz"
print("Welcome", name)
print("Hello " + name)
# Out:
# Welcome Ayaz
# Hello Ayaz

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 3-	جمع رقمين وطباعة الناتج
# </div>

# %%
a = 5
b = 7

result = a + b

print("The sum is", result)
# Out:
# The sum is 12

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# تمرين
# المطلوب
# اكتب برنامجًا في بايثون يقوم بما يلي
# 1.	يطلب من المستخدم إدخال اسمه
# 2.	يطلب من المستخدم إدخال عمره
# 3.	يطبع جملة ترحيبية بالشكل
# </div>

# %% [markdown]
# حل التمرين

# %%
name = input("Enter your name")

age = input( "Enter your age")

print("Hello", name + " your age is", age)
# Out:
# Hello Ayaz your age is 34

# %% [markdown]
# </div>
