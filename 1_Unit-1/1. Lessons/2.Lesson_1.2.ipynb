# %% [markdown]
# <style>
# div.jp-RenderedHTMLCommon {
#     direction: rtl;
#     text-align: right;
#     font-family: "Amiri", "Arial", sans-serif;
# }
# </style>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# الوحدة الأولى – مقدمة إلى بايثون
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# (Syntax) الدرس 1.2: تركيب لغة بايثون وقواعد كتابة الكود
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 1-	استخدام المسافات البادئة داخل شرط if
# </div>

# %%
age = 20

if age >= 18:
    print("You are an adult")
# Out:
# You are an adult

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# 2-	كتابة أمر طويل في عدة أسطر
# </div>

# %%
x = 1
y = 2
z = 3

if(x>0 and
   y>0 and
   z>0):
    
    print("حميع القيم موجبة")

    total = (100 + 200+
             300 + 
             400 + 500+ 600)
    print(total)
# Out:
# حميع القيم موجبة
# 2100

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# تمرين
# المطلوب
# اكتب برنامجًا يقوم بما يلي
# 1.	يطلب من المستخدم إدخال درجة الامتحان
# 2.	إذا كانت الدرجة أكبر أو تساوي 50، يطبع "ناجح" ويطبع "مبروك"
# 3.	إذا كانت أقل من 50، يطبع "راسب" ويطبع "حاول مرة أخرى"
# 4.	التزم باستخدام المسافات البادئة والتعليقات بشكل صحيح
#
# حل التمرين
# </div>

# %%
score = int( input( "Enter ypur exam score"))

if score >= 50:
    print("ناجح")
    print("مبروك")

else:
    print("راسب")
    print("حاول مرة اخرى")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 score = int( input( "Enter ypur exam score"))
#       3 if score >= 50:
#       4     print("ناجح")
#
# ValueError: invalid literal for int() with base 10: ''
