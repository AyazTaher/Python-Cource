# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة الخامسة:   التمرين الثامن عشر  Exercise_18</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 1 (سهل): طباعة الأعداد الزوجية فقط من 1 إلى 10
#
# السؤال:
#
# اكتب برنامجًا يستخدم حلقة while لتكرار عملية طباعة الأعداد الزوجية فقط من 1 إلى 10 مرتين.
#
# يجب أن تُستخدم داخل حلقة while حلقة for للتحقق من كون العدد زوجيًا (باستخدام if) ثم طباعته.
# </div>

# %%
count = 0
while count < 2:
    print(f"Iteration number {count + 1}")
    for i in range(1, 11):
        if i % 2 == 0:
            print(i, end=" ")
            count += 1
# Out:
# Iteration number 1
# 2 4 6 8 10

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#
# التمرين 2 (سهل): جمع الأعداد الموجبة فقط
#
# السؤال:
#
# اكتب برنامجًا يطلب من المستخدم إدخال أرقام متعددة (موجبة أو سالبة).
#
# تستمر العملية حتى يُدخل المستخدم الرقم 0، وعندها يتوقف البرنامج.
#
# يجب جمع الأعداد الموجبة فقط باستخدام حلقة while خارجية وداخلها for للتحقق من الشرط.
#
# ✨ مثال:
#
# </div>

# %%
total = 0
while True:
    num = int(input("Enter a number (0 to stop): "))
    if num == 0:
        break
    for i in [num]:
        if i > 0:
            total += i
            print("Total =", total)
# Out:
# Total = 584
# Total = 682
# Total = 708
