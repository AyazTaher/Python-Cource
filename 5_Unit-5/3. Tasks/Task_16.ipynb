# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة الخامسة:   التمرين  السادس عشر  Exercise_16</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 1: الأساسي (سهل) – طباعة الأرقام من 1 إلى 10
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 2: متوسط – جمع الأرقام الزوجية من 1 إلى 20
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 3: متوسط إلى متقدم – طباعة جدول الضرب لعدد معين
#
# اطلب من المستخدم إدخال رقم، ثم اطبع جدول الضرب له من 1 إلى 10
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# المهمة 4: متقدم – رسم مثلث من النجوم باستخدام حلقات متداخلة
#
#  اطبع مثلثًا من النجوم كالتالي:
# # *
# # **
# # ***
# # ****
# # *****
#
# </div>
