# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# الوحدة الخامسة:   التمرين التاسع عشر  Exercise_19</div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# التمرين 1 (سهل)
#
# المطلوب:
# اكتب برنامجًا يطبع جميع العناصر الموجبة فقط من قائمة أعداد معطاة.
#
# البيانات المتاحة:
#
# numbers = [5, -2, 9, -1, 3, 0, -7]
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
#
# التمرين 2 (سهل)
#
# المطلوب:
# اكتب برنامجًا يقوم بحساب مجموع القيم الأكبر من 50 داخل قائمة درجات ثم طباعته.
#
# البيانات المتاحة:
#
# scores = [23, 75, 50, 88, 45, 92]
#
#
# </div>
